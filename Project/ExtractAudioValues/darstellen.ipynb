# %%
from scipy.io.wavfile import read
from scipy.io import wavfile
import matplotlib.pyplot as plt
import numpy as np
rate,data=read("data/AudioWAV/1002_IEO_NEU_XX.wav")
length = data.shape[0] / rate
#plotting the audio time and amplitude
time = np.linspace(0., length, data.shape[0])
values=list()
for i in range(data.shape[0]):
        values.append(data[i])
plt.plot(time, values, label="Audio")
plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()

# %%
import librosa
y,sr=librosa.load("data/AudioWAV/1002_IEO_NEU_XX.wav")

# %%
second = []
for s in range(0, len(y), sr):
    second.append(np.abs(y[s:s + sr]).mean())
second.sort()
median=second[len(second)//2]
segments=librosa.effects.split(y,top_db=10, ref=np.max)
segments
# Out:
# array([[18432, 19968],
#        [21504, 28672],
#        [31232, 34304]])

# %%
librosa.display.waveshow(y=y,sr=sr)

# %%
y1=y[:segments[0][0]]
y2 = y[segments[0][0]:segments[0][1]]

# %%
librosa.display.waveshow(y=y2,sr=sr)
